# %% [markdown]
# Harry
# 37.21
#
# Berry
# 37.21
#
# Tina
# 37.2
#
# Akriti
# 41
#
# Harsh
# 39

# %%
names = ["Harry", "Berry", "Tina", "Akriti", "Harsh"]
scores = [37.21, 37.21, 37.2, 41, 39]

# %%
second_lowest_score = sorted(set(scores), reverse = True)[1]
second_lowest_score
# Out:
# 39

# %%
nested = list(zip(names, scores))
nested
# Out:
# [('Harry', 37.21),
#  ('Berry', 37.21),
#  ('Tina', 37.2),
#  ('Akriti', 41),
#  ('Harsh', 39)]

# %%
[item for item in nested if item[1] == second_lowest_score]
# Out:
# [('Harsh', 39)]

# %%
filtered = [item for item in nested if item[1] == second_lowest_score]
filtered
# Out:
# [('Harsh', 39)]

# %%
sorted(nested, key = lambda x: x[1])
# Out:
# [('Tina', 37.2),
#  ('Harry', 37.21),
#  ('Berry', 37.21),
#  ('Harsh', 39),
#  ('Akriti', 41)]
